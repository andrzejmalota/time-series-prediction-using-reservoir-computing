# %%
from torch.utils.data import Dataset, DataLoader
import numpy as np

class TimeSeriesSlidingWindowDataset(Dataset):
    def __init__(self, X, y, window_size, prediction_horizon=1):
        self.X = X
        self.y = y
        self.window_size = window_size
        self.prediction_horizon = prediction_horizon - 1
        self.shape = self.__getshape__()

    def __len__(self):
        return len(self.y) - self.window_size

    def __getitem__(self, index):
        return (self.X[:, index:index+self.window_size], self.y[np.newaxis, index+self.window_size+self.prediction_horizon, np.newaxis])

    def __getshape__(self):
        return (self.__len__(), *self.__getitem__(0)[0].shape)

import pandas as pd
import torch

def build_dataset(window_size, prediction_horizon, data_path='input_data.csv'):
    data = pd.read_csv(data_path, index_col=0).iloc[::-1].reset_index(drop=True)
    X = torch.tensor(data.values).reshape(data.shape[1], data.shape[0])
    y = torch.tensor(data['close'].values)

    return TimeSeriesSlidingWindowDataset(X, y, window_size, prediction_horizon)

# %%
data = pd.read_csv('input_data.csv', index_col=0)
data
# Out:
#                        open    high     low   close  volume
# date
# 2020-10-22 20:00:00  426.30  426.58  426.30  426.49  5786.0
# 2020-10-22 19:59:00  426.69  426.69  426.25  426.50  6459.0
# 2020-10-22 19:58:00  426.39  426.67  426.37  426.67  3597.0
# 2020-10-22 19:57:00  426.40  426.50  426.40  426.50  4659.0
# 2020-10-22 19:56:00  426.30  426.40  426.30  426.40  1062.0
# ...                     ...     ...     ...     ...     ...
# 2020-10-09 04:06:00  430.75  430.75  430.75  430.75   291.0
# 2020-10-09 04:05:00  430.21  430.51  430.20  430.51  1272.0
# 2020-10-09 04:04:00  430.43  430.43  430.32  430.32   873.0
# 2020-10-09 04:02:00  430.37  430.43  430.37  430.43  1016.0
# 2020-10-09 04:01:00  429.75  430.74  429.75  430.11  2083.0
#
# [8186 rows x 5 columns]

# %%
data = pd.read_csv('input_data.csv', index_col=0)
data = data.iloc[::-1].reset_index(drop=True)
data.values.shape
# Out:
# (8186, 5)

# %%
dataset = build_dataset(2, 1)
trainloader = DataLoader(dataset, batch_size=1, shuffle=False)
# Out:
# torch.Size([5, 8186])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 429.7500,  430.7400],
#         [ 445.4900,  445.4900],
#         [ 449.2500,  449.2500],
#         [ 446.6600, 1411.0000],
#         [3146.0000,  421.0200]], dtype=torch.float64)

# %%
for x, y in trainloader:
    print(x.shape)
    print(y.shape)
# Out:
# [ 446.0000,  446.0000],
#         [ 446.0000,  446.0000],
#         [ 448.4000,  448.6000],
#         [ 421.0000, 2246.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5400,  430.7000],
#         [ 446.0000,  446.0000],
#         [ 446.0000,  446.0000],
#         [ 448.6000, 1230.0000],
#         [2246.0000,  420.8900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.7000,  430.5300],
#         [ 446.0000,  446.0000],
#         [ 446.0000, 1536.0000],
#         [1230.0000,  448.5000],
#         [ 420.8900,  420.8900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5300,  430.7000],
#         [ 446.0000,  748.0000],
#         [1536.0000,  446.0000],
#         [ 448.5000,  448.6000],
#         [ 420.8900,  420.8900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.7000, 520.0000],
#         [748.0000, 446.2600],
#         [446.0000, 446.0000],
#         [448.6000, 448.5000],
#         [420.8900, 420.8900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[520.0000, 430.5300],
#         [446.2600, 446.2600],
#         [446.0000, 446.0000],
#         [448.5000, 448.6000],
#         [420.8900, 555.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.5300, 430.5300],
#         [446.2600, 446.2600],
#         [446.0000, 446.0000],
#         [448.6000, 371.0000],
#         [555.0000, 420.9900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5300,  430.5300],
#         [ 446.2600,  446.2600],
#         [ 446.0000, 3339.0000],
#         [ 371.0000,  448.7500],
#         [ 420.9900,  420.9900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5300,  430.5300],
#         [ 446.2600,  314.0000],
#         [3339.0000,  446.2500],
#         [ 448.7500,  448.7500],
#         [ 420.9900,  420.8000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.5300, 230.0000],
#         [314.0000, 446.2000],
#         [446.2500, 446.6400],
#         [448.7500, 448.7500],
#         [420.8000, 420.8000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[230.0000, 430.3500],
#         [446.2000, 446.2000],
#         [446.6400, 446.0000],
#         [448.7500, 448.7500],
#         [420.8000, 959.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.3500, 430.3500],
#         [446.2000, 446.2000],
#         [446.0000, 446.6400],
#         [448.7500, 257.0000],
#         [959.0000, 420.8700]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.3500,  430.3500],
#         [ 446.2000,  446.2000],
#         [ 446.6400, 2720.0000],
#         [ 257.0000,  448.0000],
#         [ 420.8700,  420.8800]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.3500,  430.3500],
#         [ 446.2000,  220.0000],
#         [2720.0000,  446.4500],
#         [ 448.0000,  448.0000],
#         [ 420.8800,  420.7500]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.3500, 323.0000],
#         [220.0000, 446.4500],
#         [446.4500, 446.4500],
#         [448.0000, 447.9900],
#         [420.7500, 420.7500]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 323.0000,  430.2200],
#         [ 446.4500,  446.4500],
#         [ 446.4500,  446.0000],
#         [ 447.9900,  447.9900],
#         [ 420.7500, 1248.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.2200,  430.2200],
#         [ 446.4500,  446.4500],
#         [ 446.0000,  446.0000],
#         [ 447.9900, 1845.0000],
#         [1248.0000,  420.6900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.2200,  430.2100],
#         [ 446.4500,  446.4500],
#         [ 446.0000, 1285.0000],
#         [1845.0000,  447.9900],
#         [ 420.6900,  421.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.2100,  430.2100],
#         [ 446.4500,  496.0000],
#         [1285.0000,  446.2000],
#         [ 447.9900,  447.9900],
#         [ 421.0000,  420.4300]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.2100, 434.0000],
#         [496.0000, 447.0000],
#         [446.2000, 446.2000],
#         [447.9900, 447.8000],
#         [420.4300, 420.5000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 434.0000,  430.2200],
#         [ 447.0000,  447.1000],
#         [ 446.2000,  445.0300],
#         [ 447.8000,  447.8000],
#         [ 420.5000, 4874.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.2200,  430.2200],
#         [ 447.1000,  447.0000],
#         [ 445.0300,  445.0300],
#         [ 447.8000,  712.0000],
#         [4874.0000,  420.6900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.2200,  430.2100],
#         [ 447.0000,  447.1000],
#         [ 445.0300, 1820.0000],
#         [ 712.0000,  447.5500],
#         [ 420.6900,  420.6900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.2100,  430.2100],
#         [ 447.1000, 2418.0000],
#         [1820.0000,  445.0000],
#         [ 447.5500,  447.5500],
#         [ 420.6900,  420.6900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.2100,  433.0000],
#         [2418.0000,  447.5000],
#         [ 445.0000,  445.0100],
#         [ 447.5500,  447.5500],
#         [ 420.6900,  420.6900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[433.0000, 430.7000],
#         [447.5000, 447.8000],
#         [445.0100, 444.8800],
#         [447.5500, 447.5500],
#         [420.6900, 431.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.7000, 431.0000],
#         [447.8000, 447.5000],
#         [444.8800, 444.8800],
#         [447.5500, 312.0000],
#         [431.0000, 420.6900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 431.0000,  430.7000],
#         [ 447.5000,  447.8000],
#         [ 444.8800, 5016.0000],
#         [ 312.0000,  448.0000],
#         [ 420.6900,  420.6900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.7000,  431.0000],
#         [ 447.8000, 1417.0000],
#         [5016.0000,  444.1300],
#         [ 448.0000,  448.0000],
#         [ 420.6900,  420.3000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 431.0000,  813.0000],
#         [1417.0000,  447.7800],
#         [ 444.1300,  444.1300],
#         [ 448.0000,  448.0000],
#         [ 420.3000,  420.3000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[813.0000, 430.7500],
#         [447.7800, 448.0000],
#         [444.1300, 444.0100],
#         [448.0000, 448.0000],
#         [420.3000, 957.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.7500, 430.7500],
#         [448.0000, 447.7800],
#         [444.0100, 444.0100],
#         [448.0000, 225.0000],
#         [957.0000, 420.5000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.7500,  430.7500],
#         [ 447.7800,  448.0000],
#         [ 444.0100, 2241.0000],
#         [ 225.0000,  448.1000],
#         [ 420.5000,  420.5900]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.7500,  430.7500],
#         [ 448.0000, 2140.0000],
#         [2241.0000,  444.0200],
#         [ 448.1000,  448.1000],
#         [ 420.5900,  420.3000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.7500,  309.0000],
#         [2140.0000,  447.7300],
#         [ 444.0200,  444.0200],
#         [ 448.1000,  448.1000],
#         [ 420.3000,  420.3000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 309.0000,  430.8000],
#         [ 447.7300,  448.3400],
#         [ 444.0200,  444.0000],
#         [ 448.1000,  448.1000],
#         [ 420.3000, 1249.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.8000,  430.8000],
#         [ 448.3400,  447.7300],
#         [ 444.0000,  444.0000],
#         [ 448.1000,  277.0000],
#         [1249.0000,  420.5100]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.8000,  430.8000],
#         [ 447.7300,  448.0000],
#         [ 444.0000, 2055.0000],
#         [ 277.0000,  448.0000],
#         [ 420.5100,  420.8200]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.8000,  430.8000],
#         [ 448.0000, 5421.0000],
#         [2055.0000,  443.3100],
#         [ 448.0000,  448.0000],
#         [ 420.8200,  420.5100]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.8000,  147.0000],
#         [5421.0000,  447.9300],
#         [ 443.3100,  443.4600],
#         [ 448.0000,  448.0000],
#         [ 420.5100,  420.8200]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 147.0000,  430.8000],
#         [ 447.9300,  447.9800],
#         [ 443.4600,  442.6000],
#         [ 448.0000,  448.0000],
#         [ 420.8200, 2308.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.8000,  430.8000],
#         [ 447.9800,  447.9300],
#         [ 442.6000,  442.6000],
#         [ 448.0000,  348.0000],
#         [2308.0000,  421.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.8000,  430.7900],
#         [ 447.9300,  447.9800],
#         [ 442.6000, 4073.0000],
#         [ 348.0000,  447.7000],
#         [ 421.0000,  421.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.7900,  430.7900],
#         [ 447.9800,  768.0000],
#         [4073.0000,  442.5100],
#         [ 447.7000,  447.7000],
#         [ 421.0000,  421.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.7900, 702.0000],
#         [768.0000, 447.5000],
#         [442.5100, 442.6200],
#         [447.7000, 447.7000],
#         [421.0000, 421.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 702.0000,  430.2600],
#         [ 447.5000,  447.5000],
#         [ 442.6200,  442.0200],
#         [ 447.7000,  447.7000],
#         [ 421.0000, 1110.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.2600,  430.2600],
#         [ 447.5000,  447.5000],
#         [ 442.0200,  442.6200],
#         [ 447.7000,  490.0000],
#         [1110.0000,  421.1000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.2600,  430.2600],
#         [ 447.5000,  447.5000],
#         [ 442.6200, 2878.0000],
#         [ 490.0000,  447.6500],
#         [ 421.1000,  421.2500]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.2600,  430.2600],
#         [ 447.5000, 1612.0000],
#         [2878.0000,  442.9000],
#         [ 447.6500,  447.6500],
#         [ 421.2500,  421.1000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.2600,  243.0000],
#         [1612.0000,  447.8900],
#         [ 442.9000,  444.9300],
#         [ 447.6500,  447.6500],
#         [ 421.1000,  421.2500]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 243.0000,  430.9000],
#         [ 447.8900,  447.9000],
#         [ 444.9300,  442.9000],
#         [ 447.6500,  447.6500],
#         [ 421.2500, 1044.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.9000,  430.9000],
#         [ 447.9000,  447.6000],
#         [ 442.9000,  444.9300],
#         [ 447.6500,  190.0000],
#         [1044.0000,  421.1000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.9000,  430.9000],
#         [ 447.6000,  447.6000],
#         [ 444.9300, 3996.0000],
#         [ 190.0000,  447.5000],
#         [ 421.1000,  421.1100]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.9000,  430.9000],
#         [ 447.6000, 1670.0000],
#         [3996.0000,  445.0100],
#         [ 447.5000,  447.5000],
#         [ 421.1100,  420.9600]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.9000,  364.0000],
#         [1670.0000,  447.5200],
#         [ 445.0100,  445.7200],
#         [ 447.5000,  447.5000],
#         [ 420.9600,  420.9600]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 364.0000,  430.5100],
#         [ 447.5200,  447.5200],
#         [ 445.7200,  444.9000],
#         [ 447.5000,  447.5000],
#         [ 420.9600, 2770.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5100,  430.5100],
#         [ 447.5200,  447.3000],
#         [ 444.9000,  445.7200],
#         [ 447.5000,  653.0000],
#         [2770.0000,  421.2500]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5100,  430.5100],
#         [ 447.3000,  447.3000],
#         [ 445.7200, 2131.0000],
#         [ 653.0000,  447.6900],
#         [ 421.2500,  421.5000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5100,  430.5100],
#         [ 447.3000, 2435.0000],
#         [2131.0000,  446.0100],
#         [ 447.6900,  447.6900],
#         [ 421.5000,  421.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5100,  234.0000],
#         [2435.0000,  447.2500],
#         [ 446.0100,  446.0100],
#         [ 447.6900,  447.6900],
#         [ 421.0000,  421.5000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 234.0000,  430.5000],
#         [ 447.2500,  447.6200],
#         [ 446.0100,  445.0000],
#         [ 447.6900,  447.6900],
#         [ 421.5000, 2161.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5000,  430.5000],
#         [ 447.6200,  447.2500],
#         [ 445.0000,  445.0000],
#         [ 447.6900,  227.0000],
#         [2161.0000,  421.5100]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5000,  430.5000],
#         [ 447.2500,  447.5600],
#         [ 445.0000, 2952.0000],
#         [ 227.0000,  447.6800],
#         [ 421.5100,  421.9000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5000,  430.5000],
#         [ 447.5600, 1640.0000],
#         [2952.0000,  445.0000],
#         [ 447.6800,  447.6800],
#         [ 421.9000,  421.5100]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5000,  230.0000],
#         [1640.0000,  447.5700],
#         [ 445.0000,  445.0000],
#         [ 447.6800,  447.6800],
#         [ 421.5100,  421.9000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 230.0000,  430.3300],
#         [ 447.5700,  447.5700],
#         [ 445.0000,  445.0000],
#         [ 447.6800,  447.6800],
#         [ 421.9000, 9809.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.3300,  430.3300],
#         [ 447.5700,  447.5700],
#         [ 445.0000,  445.0000],
#         [ 447.6800,  406.0000],
#         [9809.0000,  421.4500]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.3300, 430.2500],
#         [447.5700, 447.5700],
#         [445.0000, 721.0000],
#         [406.0000, 447.6800],
#         [421.4500, 421.5000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.2500, 430.2500],
#         [447.5700, 393.0000],
#         [721.0000, 445.0300],
#         [447.6800, 447.6800],
#         [421.5000, 421.4500]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.2500, 338.0000],
#         [393.0000, 447.6100],
#         [445.0300, 445.1600],
#         [447.6800, 447.6800],
#         [421.4500, 421.5000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[338.0000, 430.5000],
#         [447.6100, 447.6100],
#         [445.1600, 445.0300],
#         [447.6800, 447.6800],
#         [421.5000, 807.0000]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.5000, 430.5000],
#         [447.6100, 447.6100],
#         [445.0300, 445.1600],
#         [447.6800, 206.0000],
#         [807.0000, 421.2500]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5000,  430.5000],
#         [ 447.6100,  447.6100],
#         [ 445.1600, 1285.0000],
#         [ 206.0000,  447.1000],
#         [ 421.2500,  421.2500]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[ 430.5000,  430.5000],
#         [ 447.6100,  372.0000],
#         [1285.0000,  445.0000],
#         [ 447.1000,  447.1000],
#         [ 421.2500,  421.2500]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# torch.Size([5, 2])
# tensor([[430.5000, 120.0000],
#         [372.0000, 447.8900],
#         [445.0000, 445.0000],
#         [447.1000, 447.1000],
#         [421.2500, 421.2500]], dtype=torch.float64)
# torch.Size([1, 0, 8186])
# torch.Size([1, 1, 1])
# torch.Size([5, 8186])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-8c01dd7552b5> in <module>
# ----> 1 for x, y in trainloader:
#       2     print(x.shape)
#       3     print(y.shape)
#
# ~\miniconda3\envs\py38\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     361
#     362     def __next__(self):
# --> 363         data = self._next_data()
#     364         self._num_yielded += 1
#     365         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~\miniconda3\envs\py38\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     401     def _next_data(self):
#     402         index = self._next_index()  # may raise StopIteration
# --> 403         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     404         if self._pin_memory:
#     405             data = _utils.pin_memory.pin_memory(data)
#
# ~\miniconda3\envs\py38\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~\miniconda3\envs\py38\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-102-e12f0ac8f1ff> in __getitem__(self, index)
#      14
#      15     def __getitem__(self, index):
# ---> 16         print(self.X.shape)
#      17         print(self.X[:, index:index+self.window_size].shape)
#      18         print(self.X[:, index:index+self.window_size])
#
# ~\miniconda3\envs\py38\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\miniconda3\envs\py38\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\miniconda3\envs\py38\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     414                                  copy_threshold=self.copy_threshold)
#     415             data.group = group
# --> 416         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     417
#     418     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\miniconda3\envs\py38\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
